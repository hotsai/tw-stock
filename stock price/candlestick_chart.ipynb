# %%
# @title
import pandas as pd
import matplotlib.pyplot as plt
import plotly.graph_objects as go
import yfinance as yf
from datetime import datetime

plt.style.use('fivethirtyeight')

stock_id = '  2330.TW'
start_date = '2022-01-01'
end_date = '2024-01-01'

# 下載股票價格資料
price_df = yf.download(stock_no, start=start_date, end=end_date)

figure = go.Figure(
    data=[
        go.Candlestick(
            x=price_df.index,
            open=price_df['Open'],
            high=price_df['High'],
            low=price_df['Low'],
            close=price_df['Close'],
            increasing_line_color='red',
            decreasing_line_color='green'
        )
    ]
)

# 啟用時間區段選取的滑塊
figure.update_layout(xaxis_rangeslider_visible=True)

# 計算選取區段的平均價格
selected_data = price_df.loc[datetime.strptime(start_date, '%Y-%m-%d'):datetime.strptime(end_date, '%Y-%m-%d')]  # 修改選取的時間範圍
average_price = selected_data['Close'].mean()

# 更新圖表佈局
figure.update_layout(
    title=f'Stock Price\nAverage Price in Selected Period: {average_price:.2f}',
    xaxis_title='Date',
    yaxis_title='Price',
)

print('Stock no.: ', stock_id)
print('Time:', start_date, '~', end_date)
figure.show()
# Out:
# [*********************100%%**********************]  1 of 1 completed
# Stock no.:    2330.TW
# Time: 2022-01-01 ~ 2024-01-01
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...
