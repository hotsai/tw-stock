# %% [markdown]
# https://mops.twse.com.tw/nas/t21/otc/t21sc03_112_11_0.html

# %%
import pandas as pd
import requests
from io import StringIO
import time

def monthly_report(year, month):
    # 假如是西元，轉成民國
    if year > 1990:
        year -= 1911

    # 構建網址
    url = f'https://mops.twse.com.tw/nas/t21/otc/t21sc03_{year}_{month}_0.html' if year > 98 else f'https://mops.twse.com.tw/nas/t21/otc/t21sc03_{year}_{month}.html'

    # 偽瀏覽器
    headers = {
        'User-Agent': 'Mozilla/5.0 (Macintosh; Intel Mac OS X 10_10_1) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/39.0.2171.95 Safari/537.36'
    }

    try:
        # 下載該年月的網站，並用pandas轉換成 dataframe
        r = requests.get(url, headers=headers)
        r.encoding = 'big5'
        dfs = pd.read_html(StringIO(r.text), encoding='big-5')

        # 合併符合條件的 dataframe
        df = pd.concat([df for df in dfs if 5 < df.shape[1] <= 11], ignore_index=True)

        # 設定欄位名稱
        df.columns = df.columns.get_level_values(1)
        df['year'] = year + 1911
        df['month'] = month

        # 偽停頓
        time.sleep(5)

        return df
    except Exception as e:
        print(f"Error: {e}")
        return pd.DataFrame()  # 回傳空的 DataFrame 以示錯誤

# %%
# 使用列表生成式簡化迴圈
data_frames = [monthly_report(year, month) for year in range(111, 113) for month in range(1, 13)]

# 合併所有資料
result_df = pd.concat(data_frames, ignore_index=True)

# 設定欄位名稱
result_df.columns = ['stock_id', 'company_name', 'current_month_revenue', 'last_month_revenue',
                     'last_year_current_month_revenue', 'mth_to_mth_change_percent', 'yr_to_yr_change_percent',
                     'current_month_accumulated_revenue', 'last_year_accumulated_revenue', 'ytd_change_percent',
                     'remarks', 'year', 'month']

# 避免多次重新指定結果 DataFrame
result_df = result_df[['stock_id', 'company_name', 'current_month_revenue', 'last_month_revenue',
                       'last_year_current_month_revenue', 'mth_to_mth_change_percent', 'yr_to_yr_change_percent',
                       'current_month_accumulated_revenue', 'last_year_accumulated_revenue', 'ytd_change_percent',
                       'year', 'month']]

# 在最後進行篩選
result_df = result_df[~result_df['stock_id'].isin(['合計', '全部國內上櫃公司合計'])]

# 印出結果
result_df.dtypes
# Out:
# stock_id                              object
# company_name                          object
# current_month_revenue                  int64
# last_month_revenue                     int64
# last_year_current_month_revenue        int64
# mth_to_mth_change_percent            float64
# yr_to_yr_change_percent              float64
# current_month_accumulated_revenue      int64
# last_year_accumulated_revenue          int64
# ytd_change_percent                   float64
# year                                   int64
# month                                  int64
# dtype: object

# %%
result_df['stock_id'].unique()
# Out:
# array(['德麥', '金穎生技', '中華食', '環泰', '福格創新', '綠茵', '信立', '勝昱', '世坤', '萬國通',
#        '東隆興', '福大', '新昕纖', '飛寶企業', '金洲', '元勝', '光明', '銘旺實', '興采', '雙邦',
#        '力肯', '新麥', '和勤', '宏佳騰', '世德', '嘉鋼', '精湛', '泰茂', '謚源', '精確', '至寶電',
#        '彬台', '台興', '元創精密', '健信', '金雨', '崇友', '高鋒', '福裕', '永彰', '方方土霖',
#        '江興鍛', '協易機', '慶騰', '至興', '大詠城', '萬在', '桓達', '長佳', '寶緯', '健椿',
#        '百德', '科際精密', '捷流閥業', '君帆', '擎邦', '易發', '富強鑫', '瀧澤科', '千附精密', '進典',
#        '鈦昇', '瑞穎', '大億金茂', '朋程', '皇田', '風青', '台蠟', '奇鈦科', '大恭', '磐亞',
#        '永純', '永捷', '大立', '美琪瑪', '泓瀚', '國碳科', '誠泰科技', '晶呈科技', '聚和', '精華',
#        '生泰', '合世', '訊聯', '杏昌', '易威', '寶利徠', '進階', '基亞', '佰研', '大學光', '永日',
#        '東洋', '邦特', '加捷生醫', '濟生', '健喬', '明基醫', '友華', '優盛', '晟德', '太醫',
#        '天良', '中天', '聯合', '健亞', '浩泰', '曜亞', '中裕', '鈺緯', '訊聯基因', '聿新科',
#        '智擎', '鐿鈦', '松瑞藥', '醣聯', '久裕', '浩鼎', '杏一', '福永生技', '安克', '杏國',
#        '欣大健康', '永昕', '雙美', '豪展', '合一', '皇將', '強生製藥', '德英', '寶島科', '上亞科技',
#        '立康', '藥華藥', '益得', '大樹', '生華科', '科懋', '益安', '達爾膚', '明達醫', '順藥',
#        '高端疫苗', '醫揚', '霈方', '逸達', '台康生技', '奈米醫材', '慧智', '台生材', '威健生技',
#        '樂斯科', '軒郁', '長聖', '博晟生醫', '亨泰光', '達亞', '台微醫', '長佳智能', '生展', '盛弘',
#        '商之器', '東生華', '大江', '唐榮公司', '世鎧', '晉椿', '世豐', '雄順', '榮剛', '久陽',
#        '強新', '建錩', '華祺', '松和', '沛波', '�矬ㄟ篕�', '大國鋼', '青鋼', '有益', '穩懋',
#        '笙泉', '晶宏', '亞信', '公準', '原相', '金麗科', '鑫創', '威剛', '欣銓', '台星科',
#        '海德威', '尼克森', '典範', '精材', '類比科', '聚積', '力旺', '博士旺', '禾瑞亞', '逸昌',
#        '博磊', '德微', '家登', '漢磊', '力士', '陞達科技', '精拓科', '廣穎電通', '凌陽創新', '笙科',
#        '信驊', '杰力', '太欣', '世紀', '立衛', '世界', '鈺創', '台半', '凱鈺', '中美晶', '通泰',
#        '合邦', '創惟', '普誠', '茂達', '頎邦', '合晶', '瑞築', '旺矽', '研通', '旺玖', '驊訊',
#        '久元', '元隆', '沛亨', '晶焱', '大中', '紘康', '神盾', '點序', '環球晶', '九齊', '精測',
#        '瑞耘', '長科*', '宏觀', '均華', 'M31', '全宇昕', '鈺太', '雍智科技', '安格', '廣閎科',
#        '天擎', '應廣', '昇佳電子', '華景電', '濾能', '意德士科技', '佑華', '九暘', '安國', '宏捷科',
#        '品安', '巨有科技', '商丞', '群聯', '濱川', '協禧', '艾訊', '順達', '茂訊', '東碩',
#        '廣寰科', '加百裕', '旭品', '寶德', '安勤', '力致', '鴻翊', '曜越', '泓格', '磐儀', '鼎翰',
#        '西勝', '營邦', '鑫聯大投控', '新盛力', '科誠', '宜鼎', '協益', '青雲', '振發', '東友',
#        '富驊', '聰泰', '同亨', '新普', '撼訊', '欣技', '捷波', '廣明', '全譜', '安鈦克', '廣錠',
#        '維田', '勁豐', '鑫創電子', '宸曜', '廣積', '伍豐', '新漢', '森田', '李洲', '昇銳', '錦明',
#        '杭特', '泰谷', '先進光', '哲固', '聯一光電', '由田', '單井', '亞帝歐', '迎輝', '先益',
#        '安可', '富晶通', '新鉅科', '光耀', '碩禾', '熒茂', '友輝', '湯石照明', '晶達', '萬達光電',
#        '雷笛克光學', '智晶', '天鉞電', '光聯', '中光電', '能率', '新門', '均豪', '廣運', '久正',
#        '上揚', '高僑', '茂迪', '臺龍', '京晨科', '保勝光學', '勝品', '欣普羅', '伯特光', '邑錡',
#        '晶采', '東捷', '元太', '立��', '華宏', '聯亞', '及成', '璟德', '波若威', '台嘉碩',
#        '光環', '鼎天', '上詮', '德晉', '昇達科', '環天科', '神準', '其陽', '研勤', '康聯訊',
#        '榮昌', '聯光通', '台聯電', '前鼎', '新復興', '華星光', '正能量智能', '台林', '亞元', '振曜',
#        '華電網', '統振', '萬泰科', '豪勉', '易通展', '立端', '普萊德', '韋僑', '威潤', '宇智',
#        '互動', '創威', '正基', '是方', '東典', '榮群', '德勝', '凱碩', '康全電訊', '常珵', '智捷',
#        '台翰', '川寶', '富喬', '僑威', '億杰', '好德', '富榮綱', '雲嘉南科技', '樺晟', '志豐',
#        '耀勝', '優群', '千如', '宇環', '點晶', '東浦', '英濟', '佳穎', '建舜電', '幸康', '律勝',
#        '臺慶科', '崇越電', '旭軟', '進泰電子', '崧騰', '長盛', '矽瑪', '華盈', '凡甲', '堡達',
#        '兆利', '映興', '三一東林', '光頡', '晟楠', '艾恩特', '湧德', '連展投控', '科嶠', '亞電',
#        '亞泰', '鈺鎧', '邑昇', '系統電', '華容', '建榮', '佳總', '合正', '高技', '宣德', '同協',
#        '霖宏', '德宏', '松普', '凱崴', '久威', '業強', '信音', '九豪', '萬旭', '松上', '禾昌',
#        '信昌電', '安��', '立敦', '幃翔', '育富', '海韻電', '艾華', '雷科', '日揚', '慶生',
#        '中探針', '岳豐', '百徽', '泰詠', '台燿', '元山', '胡連', '佳邦', '良維', '迅德', '詠昇',
#        '今展科', '倉和', '南俊國際', '富致', '群翊', '亞泰金屬', '穩得', '聯寶', '長園科', '金山電',
#        '蜜望實', '能率網通', '鉅橡', '翔名', '保銳', '博大', '越峰', '正淩', '博智', '加高',
#        '泰藝', '尚茂', '金居', '三顧', '昱捷', '尚立', '利機', '亞矽', '建達', '順發', '茂綸',
#        '方土昶', '倍微', '光菱', '志旭', '全達', '巨虹', '擎亞', '大綜', '大塚', '緯軟', '凱衛',
#        '力新', '寶碩', '蒙恬', '凌網', '天剛', '中菲', '國眾', '上奇', '訊達電腦', '驊宏資',
#        '晉泰', '系微', '勤崴國際', '普鴻', '台灣銘板', '東捷資訊', '智聯服務', '叡揚', '虎門科技',
#        '偉康科技', '倍力', '大世科', '三竹', '實威', '光洋科', '全域', '港建*', '弘塑', '倚強科',
#        '微端', '宜特', '岱稜', '雙鴻', '熱映', '漢科', '陽程', '位速', '西柏', '同致', '友威科',
#        '閎康', '盈正', '鑫科', '橙的', '達航科技', '勤凱科技', '金利', '佶優', '彩富', '三聯',
#        '聖暉*', '耕興', '晉倫', '萬潤', '啟發電', '朋億*', '天正國際', '信紘科', '美達科技',
#        '東研信超', '數泓科', '鏵友益', '星雲', '福華', '建暐', '精星', '千附', '匯鑽科', '欣雄',
#        '欣泰', '北基', '大汽電', '綠意', '晶悅', '鑫龍騰', '森寶', '皇龍', '聯上', '三圓', '富宇',
#        '坤悅', '亞昕', '士開', '昇益', '永信建', '德昌', '力麒', '三豐', '雙喜', '力泰', '豐謙',
#        '鉅陞', '大城地產', '新潤', '理銘', '富旺', '富裔', '印鉐', '惠普', '正德', '捷迅',
#        '台聯櫃', '陸海', '中菲行', '安心', '漢來美食', '燦星旅', '瓦城', '六角', '易飛網', '富野',
#        '天蔥', '山富', '五福', '豆府', '亞洲藏壽司', '揚秦', '聯發國際', '海灣', '御頂', '宏易',
#        '寶得利', '力麗店', '劍湖山', '亞都麗緻', '老爺知', '南仁湖', '洛��', '致和證', '台名',
#        '宏遠證', '康和證', '大展證', '美好證', '元大期貨', '福邦證', '精剛', '大甲', '太普高', '斐成',
#        '耀億', '淳紳', '晟田', '旭然', '牧東', '新鼎', '天揚', '慕康生醫', '南良', '新華', '龍巖',
#        '中連', '亞通', '天品', '中湛', '松崗', '信實', '益張', '冠好', '白紗科', '旭源', '鉅邁',
#        '三貝德', '裕國', '花王', '光隆', '沈氏', '富堡', '智通', '邦泰', '國統', '合騏', '森鉅',
#        '誠品生活', '泰偉', '網龍', '華義', '鈊象', '宇峻', '地心引力', '昇華', '辣椒', '智崴',
#        '智冠', '寬魚國際', '大宇資', '得利影', '昱泉', '橘子', '智基', '弘煜科', '隆中', '寬宏藝術',
#        '鑫傳', '華研', '霹靂', '時報', '琉園', '茂生農經', '瑞基', '惠光', '達邦蛋白', '天方能源',
#        '世禾', '新晶投控', '中茂', '萬年清', '崑鼎', '華鎂鑫', '天宇', '金益鼎', '綠電', '大車隊',
#        '新零售', '歐買尬', '尚凡', '數字', '美而快', '安�硌穈T', '綠界科技', '宏�硌穈T', '騰雲',
#        '網家', '夠麻吉', '創業家', '祺驊', '明係', '明揚', '大田', '鉅明', '愛地雅', '明安',
#        '邁達康', '滿心', '集雅社', '振宇五金', '寶陞', '新洲', '唐鋒', '中美實', '德記', '全家',
#        '寶雅', '詩肯', '上洋', '來思達', '弘帆', '關中', '宏碩系統', '衛司特', '伯鑫', '欣新網'],
#       dtype=object)

# %%
result_df.tail(3)
# Out:
#          stock_id company_name  current_month_revenue  last_month_revenue  \
# 18882        6811        宏�硌穈T                 886976              324550
# 18884        6804           明係                 276383              240809
# 18886  全部國內上櫃公司合計   全部國內上櫃公司合計               37971672            40797741
#
#        last_year_current_month_revenue  mth_to_mth_change_percent  \
# 18882                           860189                     173.29
# 18884                           304364                      14.77
# 18886                         37362846                      -6.92
#
#        yr_to_yr_change_percent  current_month_accumulated_revenue  \
# 18882                     3.11                            7545564
# 18884                    -9.19                            3363294
# 18886                     1.62                          434399438
#
#        last_year_accumulated_revenue  ytd_change_percent  year  month
# 18882                        7201012                4.78  2023     12
# 18884                        3322572                1.22  2023     12
# 18886                      476056365               -8.75  2023     12

# %%
result_df = result_df[result_df['stock_id'] != '全部國內上櫃公司合計']

# %%
result_df.shape
# Out:
# (18197, 12)

# %%
import pandas as pd
from google.cloud import bigquery
from pandas_gbq import to_gbq, read_gbq
from google.colab import drive
from google.oauth2 import service_account

drive.mount('/content/gdrive')

# 設定你的Google Cloud帳戶認證檔案路徑
credentials_path = '/content/gdrive/My Drive/tw-stock.json'

# 設定你的BigQuery專案ID
project_id = 'tw-stock-410406'

# Load credentials using google.oauth2.service_account
credentials_obj = service_account.Credentials.from_service_account_file(credentials_path)

# 從BigQuery中讀取資料
read_df = read_gbq(f'SELECT COUNT(*) as row_count FROM {project_id}.financial_data.monthly_revenue', project_id=project_id, credentials=credentials_obj, location='US')
read_df['row_count'][0]
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).
# Downloading: 100%|██████████|
# 21178

# %%
# 讀取目前表格的資料
current_data = read_gbq(f'SELECT COUNT(*) as row_count FROM {project_id}.financial_data.monthly_revenue', project_id=project_id, credentials=credentials_obj, location='US')
current_data_count = current_data['row_count'][0]

# 將DataFrame寫入BigQuery
to_gbq(result_df, destination_table=f'{project_id}.financial_data.monthly_revenue', project_id=project_id, if_exists='append', credentials=credentials_obj, location='US')

# 驗證資料筆數
new_data = read_gbq(f'SELECT COUNT(*) as row_count FROM {project_id}.financial_data.monthly_revenue', project_id=project_id, credentials=credentials_obj, location='US')
new_data_count = new_data['row_count'][0]

# 判斷是否寫入
if current_data_count + len(result_df) == new_data_count:
    print("資料寫入成功")
    print('寫入前資料數：', current_data_count)
    print('寫後資料數：', len(result_df))
    print('寫入後資料數：', new_data_count)
else:
    print("資料寫入失敗，筆數不符合預期")
    print('寫入前資料數：', current_data_count)
    print('寫後資料數：', len(result_df))
    print('寫入後資料數：', new_data_count)
# Out:
# Downloading: 100%|██████████|
# 100%|██████████| 1/1 [00:00<00:00, 1620.67it/s]
# Downloading: 100%|██████████|
# 資料寫入成功
# 寫入前資料數： 21178
# 寫後資料數： 18197
# 寫入後資料數： 39375

# %%
# import pandas as pd
# from google.cloud import bigquery
# from pandas_gbq import to_gbq, read_gbq
# from google.colab import drive
# from google.oauth2 import service_account

# drive.mount('/content/gdrive')

# # 設定你的Google Cloud帳戶認證檔案路徑
# credentials_path = '/content/gdrive/My Drive/tw-stock.json'

# # 設定你的BigQuery專案ID
# project_id = 'tw-stock-410406'

# # Load credentials using google.oauth2.service_account
# credentials_obj = service_account.Credentials.from_service_account_file(credentials_path)
# # 將DataFrame寫入BigQuery
# to_gbq(result_df, destination_table=f'{project_id}.financial_data.monthly_revenue', project_id=project_id, if_exists='replace', credentials=credentials_obj, location='US')

# # 從BigQuery中讀取資料
# read_df = read_gbq(f'SELECT COUNT(*) as row_count FROM {project_id}.financial_data.monthly_revenue', project_id=project_id, credentials=credentials_obj, location='US')
# Out:
# Mounted at /content/gdrive
# 100%|██████████| 1/1 [00:00<00:00, 7869.24it/s]

# %%
# 從BigQuery中讀取資料
read_df = read_gbq(f'SELECT COUNT(*) as row_count FROM {project_id}.financial_data.monthly_revenue', project_id=project_id, credentials=credentials_obj, location='US')
print(read_df)
# Out:
# Downloading: 100%|██████████|
#    row_count
# 0      21178
